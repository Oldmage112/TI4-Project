# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Oldmage112/TI4-Project/refs/heads/main/PowerBI/Derived%20CSVs/stgScoredPoints.csv'
df = pd.read_csv(url, low_memory=False, index_col= -1)
df = df.fillna('')

# %%
for column in df.columns[1:]:
    if 'Support for the Throne' in column:
